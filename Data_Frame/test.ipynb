# %%
from module.scraping import scraping_result
from module.csv_manager import read_csv
import pandas as pd

# %%
file_path = '../csv/race_id_(2023, 1)_(2023, 3).csv'
race_ids = read_csv(file_path)

# %%
results = []
for id in race_ids:
    results.append(scraping_result(id))

# %%
df = pd.concat(results, ignore_index=True)

# %%
df
# Out:
#     着 順  枠  馬 番         馬名  性齢    斤量   騎手     タイム     着差   人 気  単勝 オッズ   後3F  \
# 0     1  7   14  シュバルツガイスト  牡3  56.0   武豊  1:12.6    NaN   1.0     1.8  38.1
# 1     2  3    5  ジェイケイファイン  牡3  56.0  内田博  1:12.9  1.3/4   3.0     7.4  38.9
# 2     3  1    1      レディアス  牝3  54.0   津村  1:12.9     クビ   6.0    36.1  37.7
# 3     4  8   15  ハローマイラブリー  牝3  54.0   三浦  1:13.4      3   2.0     4.2  39.7
# 4     5  5    9  ベアカワイコチャン  牝3  54.0   松岡  1:13.9      3   4.0     7.9  40.1
# ..   .. ..  ...        ...  ..   ...  ...     ...    ...   ...     ...   ...
# 172  10  7   12  ノーダブルディップ  牡5  58.0   津村  2:01.7     クビ   6.0    42.3  36.2
# 173  11  7   11   ウインチェレステ  牡5  58.0   松岡  2:01.8    1/2   8.0    58.7  36.7
# 174  12  5    8  パトリックハンサム  牡4  57.0   勝浦  2:02.5      4   9.0    59.8  36.6
# 175  13  6    9   パワータイショウ  牡4  56.0  ☆永野  2:02.6      1  14.0   291.7  36.3
# 176  14  4    6   スラップショット  セ5  58.0   大野  2:03.4      5  13.0   225.2  38.0
#
#         コーナー 通過順     厩舎  馬体重 (増減)    距離
# 0            5-5   美浦国枝   486(-4)  1200
# 1            4-3   美浦奥平   472(-8)  1200
# 2           10-7  美浦鈴木慎   428(+6)  1200
# 3            1-1   美浦伊坂    536(0)  1200
# 4            2-2   美浦杉浦  478(+10)  1200
# ..           ...    ...       ...   ...
# 172    13-13-6-6   美浦古賀   544(+6)  2000
# 173      1-1-1-1   美浦畠山   504(-8)  2000
# 174    10-10-9-8   美浦菊沢  472(+10)  2000
# 175  13-13-14-14   栗東村山   498(-2)  2000
# 176     2-2-4-10   美浦大竹   498(-4)  2000
#
# [177 rows x 16 columns]
